# %%
graph = [
[2,3],
[4],
[4,6],
[5],
[6,2],
[7],
[8,9],
[9],
[2]
]

# %%
graph
# Out:
# [[2, 3], [4], [4, 6], [5], [6, 2], [7], [8, 9], [9], [2]]

# %%
paths = []
path = []
def dfs(start,index,end,graph):
    path.append(index)
    if index == end:
        paths.append(path.copy())
        path.pop()

    else:
        for item in graph[index-1]:
            if item not in path:
                dfs(start,item,end,graph)
        path.pop()

dfs(1,1,6,graph)

# %%
for i,p in enumerate(paths):
    print("path %d" % i + str(p))
# Out:
# path 0[1, 2, 4, 5, 6]
# path 1[1, 3, 4, 5, 6]
# path 2[1, 3, 6]

# %%
print(paths)
# Out:
# [[1, 2, 4, 5, 6], [1, 3, 4, 5, 6], [1, 3, 6]]

# %%
paths = []
path = []
def dfs(start,index,end,graph):
    path.append(index)
    if index == end:
        paths.append(path.copy())
        path.pop()
        print("找到终点%d，得到路径，往前回溯一位，查看节点%d是否有其他路径" % (index,path[-1]))

    else:
        print("依次搜索节点%d，%d的后置节点有 %s"% (index,index,str(graph[index-1])))
        for item in graph[index-1]:
            print("搜索节点%d的后置节点%d" % (index,item))
            if item not in path:
                dfs(start,item,end,graph)
        path.pop()
    
    if path != []:
            print("节点%d的后置节点搜索完毕，往前回溯一位，查看节点%d处是否有其他路径" % (index,path[-1]))
    else:
            print("循环结束，已无其他路径！")

# %%
paths=[]
path=[]
dfs(1, 1, 9, graph)
print(paths)
# Out:
# 依次搜索节点1，1的后置节点有 [2, 3]
# 搜索节点1的后置节点2
# 依次搜索节点2，2的后置节点有 [4]
# 搜索节点2的后置节点4
# 依次搜索节点4，4的后置节点有 [5]
# 搜索节点4的后置节点5
# 依次搜索节点5，5的后置节点有 [6, 2]
# 搜索节点5的后置节点6
# 依次搜索节点6，6的后置节点有 [7]
# 搜索节点6的后置节点7
# 依次搜索节点7，7的后置节点有 [8, 9]
# 搜索节点7的后置节点8
# 依次搜索节点8，8的后置节点有 [9]
# 搜索节点8的后置节点9
# 找到终点9，得到路径，往前回溯一位，查看节点8是否有其他路径
# 节点9的后置节点搜索完毕，往前回溯一位，查看节点8处是否有其他路径
# 节点8的后置节点搜索完毕，往前回溯一位，查看节点7处是否有其他路径
# 搜索节点7的后置节点9
# 找到终点9，得到路径，往前回溯一位，查看节点7是否有其他路径
# 节点9的后置节点搜索完毕，往前回溯一位，查看节点7处是否有其他路径
# 节点7的后置节点搜索完毕，往前回溯一位，查看节点6处是否有其他路径
# 节点6的后置节点搜索完毕，往前回溯一位，查看节点5处是否有其他路径
# 搜索节点5的后置节点2
# 节点5的后置节点搜索完毕，往前回溯一位，查看节点4处是否有其他路径
# 节点4的后置节点搜索完毕，往前回溯一位，查看节点2处是否有其他路径
# 节点2的后置节点搜索完毕，往前回溯一位，查看节点1处是否有其他路径
# 搜索节点1的后置节点3
# 依次搜索节点3，3的后置节点有 [4, 6]
# 搜索节点3的后置节点4
# 依次搜索节点4，4的后置节点有 [5]
# 搜索节点4的后置节点5
# 依次搜索节点5，5的后置节点有 [6, 2]
# 搜索节点5的后置节点6
# 依次搜索节点6，6的后置节点有 [7]
# 搜索节点6的后置节点7
# 依次搜索节点7，7的后置节点有 [8, 9]
# 搜索节点7的后置节点8
# 依次搜索节点8，8的后置节点有 [9]
# 搜索节点8的后置节点9
# 找到终点9，得到路径，往前回溯一位，查看节点8是否有其他路径
# 节点9的后置节点搜索完毕，往前回溯一位，查看节点8处是否有其他路径
# 节点8的后置节点搜索完毕，往前回溯一位，查看节点7处是否有其他路径
# 搜索节点7的后置节点9
# 找到终点9，得到路径，往前回溯一位，查看节点7是否有其他路径
# 节点9的后置节点搜索完毕，往前回溯一位，查看节点7处是否有其他路径
# 节点7的后置节点搜索完毕，往前回溯一位，查看节点6处是否有其他路径
# 节点6的后置节点搜索完毕，往前回溯一位，查看节点5处是否有其他路径
# 搜索节点5的后置节点2
# 依次搜索节点2，2的后置节点有 [4]
# 搜索节点2的后置节点4
# 节点2的后置节点搜索完毕，往前回溯一位，查看节点5处是否有其他路径
# 节点5的后置节点搜索完毕，往前回溯一位，查看节点4处是否有其他路径
# 节点4的后置节点搜索完毕，往前回溯一位，查看节点3处是否有其他路径
# 搜索节点3的后置节点6
# 依次搜索节点6，6的后置节点有 [7]
# 搜索节点6的后置节点7
# 依次搜索节点7，7的后置节点有 [8, 9]
# 搜索节点7的后置节点8
# 依次搜索节点8，8的后置节点有 [9]
# 搜索节点8的后置节点9
# 找到终点9，得到路径，往前回溯一位，查看节点8是否有其他路径
# 节点9的后置节点搜索完毕，往前回溯一位，查看节点8处是否有其他路径
# 节点8的后置节点搜索完毕，往前回溯一位，查看节点7处是否有其他路径
# 搜索节点7的后置节点9
# 找到终点9，得到路径，往前回溯一位，查看节点7是否有其他路径
# 节点9的后置节点搜索完毕，往前回溯一位，查看节点7处是否有其他路径
# 节点7的后置节点搜索完毕，往前回溯一位，查看节点6处是否有其他路径
# 节点6的后置节点搜索完毕，往前回溯一位，查看节点3处是否有其他路径
# 节点3的后置节点搜索完毕，往前回溯一位，查看节点1处是否有其他路径
# 循环结束，已无其他路径！
# [[1, 2, 4, 5, 6, 7, 8, 9], [1, 2, 4, 5, 6, 7, 9], [1, 3, 4, 5, 6, 7, 8, 9], [1, 3, 4, 5, 6, 7, 9], [1, 3, 6, 7, 8, 9], [1, 3, 6, 7, 9]]

# %%
paths=[]
path=[]
dfs(1, 1, 6, graph)
# Out:
# 依次搜索节点1，1的后置节点有 [2, 3]
# 搜索节点1的后置节点2
# 依次搜索节点2，2的后置节点有 [4]
# 搜索节点2的后置节点4
# 依次搜索节点4，4的后置节点有 [5]
# 搜索节点4的后置节点5
# 依次搜索节点5，5的后置节点有 [6]
# 搜索节点5的后置节点6
# 找到终点6，得到路径，往前回溯一位，查看节点5是否有其他路径
# 节点6的后置节点搜索完毕，往前回溯一位，查看节点5处是否有其他路径
# 节点5的后置节点搜索完毕，往前回溯一位，查看节点4处是否有其他路径
# 节点4的后置节点搜索完毕，往前回溯一位，查看节点2处是否有其他路径
# 节点2的后置节点搜索完毕，往前回溯一位，查看节点1处是否有其他路径
# 搜索节点1的后置节点3
# 依次搜索节点3，3的后置节点有 [4, 6]
# 搜索节点3的后置节点4
# 依次搜索节点4，4的后置节点有 [5]
# 搜索节点4的后置节点5
# 依次搜索节点5，5的后置节点有 [6]
# 搜索节点5的后置节点6
# 找到终点6，得到路径，往前回溯一位，查看节点5是否有其他路径
# 节点6的后置节点搜索完毕，往前回溯一位，查看节点5处是否有其他路径
# 节点5的后置节点搜索完毕，往前回溯一位，查看节点4处是否有其他路径
# 节点4的后置节点搜索完毕，往前回溯一位，查看节点3处是否有其他路径
# 搜索节点3的后置节点6
# 找到终点6，得到路径，往前回溯一位，查看节点3是否有其他路径
# 节点6的后置节点搜索完毕，往前回溯一位，查看节点3处是否有其他路径
# 节点3的后置节点搜索完毕，往前回溯一位，查看节点1处是否有其他路径
# 循环结束，已无其他路径！

# %%
print(paths)
# Out:
# [[1, 2, 4, 5, 6], [1, 3, 4, 5, 6], [1, 3, 6]]
